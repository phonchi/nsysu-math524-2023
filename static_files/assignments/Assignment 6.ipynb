# %% [markdown]
# # Assignment 6

# %% [markdown]
# #### Student ID: *Double click here to fill the Student ID*
#
# #### Name: *Double click here to fill the name*

# %% [markdown]
# ## Q1 (6%)
# For parts (a) through (c), indicate which of i. through iv. is correct.
# Justify your answer.

# %% [markdown]
# (a) The lasso, relative to least squares, is:
#     <ol style="list-style-type:lower-roman">
#     <li>More flexible and hence will give improved prediction accuracy when its increase in bias is less than its decrease in variance.</li>
#     <li>More flexible and hence will give improved prediction accuracy when its increase in variance is less than its decrease in bias.</li>
#     <li>Less flexible and hence will give improved prediction accuracy when its increase in bias is less than its decrease in variance.</li>
#     <li>Less flexible and hence will give improved prediction accuracy when its increase in variance is less than its decrease in bias.</li>
#     </ol>

# %% [markdown]
# > Ans: *double click here to answer the question.*

# %% [markdown]
# (b) Repeat (a) for ridge regression relative to least squares.

# %% [markdown]
# > Ans: *double click here to answer the question.*

# %% [markdown]
# (c) Repeat (a) for non-linear methods relative to least squares.

# %% [markdown]
# > Ans: *double click here to answer the question.*

# %% [markdown]
# ## Q2 (10%)
# Suppose we estimate the regression coefficients in a linear regression
# model by minimizing
#
# $$\sum_{i=1}^n\left(y_i-\beta_0-\sum_{j=1}^{p} \beta_jx_{ij}\right)^2\ \text{subject to}\ \sum_{j=1}^{p} |\beta_j|\leq s$$
#
# for a particular value of s. For parts (a) through (e), indicate which
# of i. through v. is correct. Justify your answer.

# %% [markdown]
# (a) As we increase s from 0, the training RSS will:
#     <ol style="list-style-type:lower-roman">
#     <li>Increase initially, and then eventually start decreasing in an
# inverted U shape.</li>
#     <li>Decrease initially, and then eventually start increasing in a
# U shape.</li>
#     <li>Steadily increase.</li>
#     <li>Steadily decrease.</li>
#     <li>Remain constant.</li>
#     </ol>

# %% [markdown]
# > Ans: *double click here to answer the question.*

# %% [markdown]
# (b) Repeat (a) for test RSS.

# %% [markdown]
# > Ans: *double click here to answer the question.*

# %% [markdown]
# (c) Repeat (a) for variance.

# %% [markdown]
# > Ans: *double click here to answer the question.*

# %% [markdown]
# (d) Repeat (a) for (squared) bias.

# %% [markdown]
# > Ans: *double click here to answer the question.*

# %% [markdown]
# (e) Repeat (a) for the irreducible error.

# %% [markdown]
# > Ans: *double click here to answer the question.*

# %% [markdown]
# ## Q3 (20%)
# In this exercise, we will generate simulated data, and will then use
# this data to perform Subset Selection Methods.
#
# (Please set np.random.seed(2023) or random_state=2023)

# %% [markdown]
# (a)(1%) Use the <span style="color:red">np.random.normal()</span> function to generate a predictor $X$ of length
# $n = 100$, as well as a noise vector $\epsilon$ of length $n = 100$.

# %%
# coding your answer here.

# %% [markdown]
# (b)(1%) Generate a response vector $Y$ of length $n = 100$ according to
# the model
#
# $$Y=\beta_0 +\beta_1 X+\beta_2 X^2 +\beta_3 X^3+\epsilon$$
#
# where $\beta_0=5,\ \beta_1=2,\ \beta_2=6,\ \text{and}\ \beta_3=1$ are constants.

# %%
# coding your answer here.

# %% [markdown]
# (c)(5%) Perform best subset selection in order to choose the best model containing the predictors $X,X^2, \dots ,X^{10}$.
#
# i.Which model with 5 predictors yields lowest RSS score?
#
# ii.What is the best model obtained according to $C_p$,  BIC, and adjusted $R^2$?
#
# iii.Show some plots to provide evidence for your answer

# %%
# coding your answer here.

# %% [markdown]
# (d)(2%) Repeat (c), using forward stepwise selection. According to BIC criteria, how many features does the best model obtained have?

# %%
# coding your answer here.

# %% [markdown]
# > Ans: *double click here to answer the question.*

# %% [markdown]
# (e)(2%) Repeat (c), using backwards stepwise selection. According to BIC criteria, how many features does the best model obtained have?

# %%
# coding your answer here.

# %% [markdown]
# > Ans: *double click here to answer the question.*

# %% [markdown]
# (f)(1%) Compare best subset selection, forward stepwise selection and backwards stepwise selection.What is the best model obtained according to BIC ?

# %% [markdown]
# > Ans: *double click here to answer the question.*

# %% [markdown]
# (g)(4%) Now fit a ridge model to the simulated data, again using  $X,X^2, \dots ,X^{10}$  as predictors.
#
# i.plot the paths to get a sense of how the coefficients vary with λ .
#
# ii.Use cross-validation(K=7) to select the optimal value of  λ .
#
# iii.What is the test MSE associated with the λ value from ii.?

# %%
# coding your answer here.

# %% [markdown]
# (h)(4%) Now fit a lasso model to the simulated data, again using $X,X^2, \dots ,X^{10}$ as predictors.
#
# i.Use cross-validation(K=5) to select the optimal
# value of $\lambda$.
#
# ii.Plot the coefficient plot of the standardized coefficients,Report the
# results obtained.

# %%
# coding your answer here.

# %% [markdown]
# > Ans: *double click here to answer the question.*
