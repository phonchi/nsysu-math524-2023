# %% [markdown]
# # Chapter 1 - Introduction

# %% [markdown]
# #### Student ID:
#
# #### Name:

# %% [markdown]
# ### Q1: In the following step, we will check the python environment.

# %% [markdown]
# (a) Check if the python version is `3.10` using following code.

# %%
# !python --version

# %% [markdown]
# If your python version is not `3.10`, install the required version.

# %% [markdown]
# (b) Confirm the version of NumPy, Pandas, and Matplotlib by printing `__version__` attribute in each package.
# If the version of NumPy, Pandas, and Matplotlib is not `1.23.5`, `2.1.0`, `3.7.1`, respectively, or if you did not install these package, then try to install the specific version.

# %%
import numpy as np
import pandas as pd
import matplotlib

# %% [markdown]
# ### Q2: Please respond to the following question regarding the proficiency in basic Python programming.

# %% [markdown]
# (a) Make a Python built-in list object that contains integers 1, 2, 3, and string '4', and assign the list to `list1`.
# Construct a NumPy array named `array1`, using the `list1`.
# What is the data type of the first element in the list `list`? What is the data type of the first element in the `array1`?

# %% [markdown]
# (b) Define a function named `foo` that return a tuple containing several float numbers. The first value of the tuple is 9.0, and the rest of the values are the odd integers between 0 and 10, ordered from least to greatest. You must use the "for loop" and mod operation.

# %% [markdown]
# (c) Execute following code:

# %%
try:
    # 1
    assert {"1", "3", "2"} == {*array1[:3]}
    # 2
    assert True or 1/0
    # 3
    assert 0+2j
    # 4
    assert array1[[0, 2]].tolist() == [str(i) for i in range(4) if i %2==1]
    # 5
    assert type(True & 0 == 3 or 2) is bool
except AssertionError:
    print("😕")

# %% [markdown]
# Which line raise an error?

# %% [markdown]
# > Ans.

# %% [markdown]
# (d) [***scikit-learn***](https://scikit-learn.org/stable/index.html) is a machine learning package that will be frequently utilized in the upcoming lessons. Within *scikit-learn*, there is a function known as `train_test_split` which aids in splitting the dataset into a training set and a test set. This is achieved by using optional keyword-only arguments, specifically `test_size` or `train_size`, which can be used to customize the splitting process.
#
# What value will `test_size` be set to if neither `test_size` nor `train_size` are explicitly provided?

# %% [markdown]
# > Ans.

# %% [markdown]
# ### Q3: In this section, we will perform EDA on a simple dataset.

# %% [markdown]
# (a) Iris dataset, aka Fisher's Iris dataset, is a dataset widely used in statistics or machine learning. Try to find the dataset in csv format on the internet. Download the file or copy the url.
# (Even though there are packages that can load iris data directly such as `datasets.load_iris()` in scikit-learn, we are not using them.)

# %% [markdown]
# (b) Read the csv file or url using `read_csv` method in Pandas. Assign the DataFrame to `iris`.

# %% [markdown]
# (c) The sepal length is a continuous variable. Plot the sepal length of every Virginica in Iris dataset using distribution plot.

# %% [markdown]
# (d) The petal length and petal width are continuous variables. Plot the relationship between these two variable for all species.

# %% [markdown]
# ### Q4: Objective of statistical learning

# %% [markdown]
# (a) What would be taught in this course:
# i. Functional programming, ii. Mathematics behind statistical model, iii. Usage of statistical model, iv. How to interpret result of statistical model.

# %% [markdown]
# > Ans.

# %% [markdown]
# (b) What do you expect to learn in this course?

# %% [markdown]
# > Ans.
